# %%
import pandas as pd

df = pd.read_excel(r'/Users/khadarbashashaik/Desktop/Data Sciences/Notebook/Australia.xlsx',sheet_name='Australia by Residence',skiprows=20)
print(df.columns)
print(df.index)
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')
# RangeIndex(start=0, stop=448, step=1)

# %%
#print(df.describe())
#print(df.columns.value_counts)
#print(df.index.value_counts)
#print(df.columns.values)
#print(df.index.values)
#print(df.shape, df.dtypes)
# Out:
# (448, 43) Type        object
# Coverage    object
# OdName      object
# AREA         int64
# AreaName    object
# REG          int64
# RegName     object
# DEV          int64
# DevName     object
# 1980         int64
# 1981         int64
# 1982         int64
# 1983         int64
# 1984         int64
# 1985         int64
# 1986         int64
# 1987         int64
# 1988         int64
# 1989         int64
# 1990         int64
# 1991         int64
# 1992         int64
# 1993         int64
# 1994         int64
# 1995         int64
# 1996         int64
# 1997         int64
# 1998         int64
# 1999         int64
# 2000         int64
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# 2009        object
# 2010        object
# 2011        object
# 2012        object
# 2013        object
# dtype: object

# %%
df.columns = [str(col) for col in df.columns]
print(df.columns)
# Out:
# Index(['Type', 'Coverage', 'OdName', 'AREA', 'AreaName', 'REG', 'RegName',
#        'DEV', 'DevName', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013'],
#       dtype='object')

# %%
import numpy as np
#print(df.columns.dtype)
#print(df.dtypes)
#df.drop(df[df['Type']=='Emigrants'].index,inplace = True)
#print(df)
#print(df.describe())
for col in df.columns:
    for i in df[col]:
        if (i == '..'):
            df[col] = np.nan
for col in df.columns:
    if df[col].isnull().any():
        if(df[col].isnull().all()):
            df.drop([col],axis = 1, inplace = True)

#print(df.dropna(axis=1, inplace = True))
#df.drop(['Type','Coverage','AREA','REG','DEV'],axis=1,inplace = True)

df.rename(columns = {'OdName':'Country',
                   'RegName':'Region'}, inplace = True)
print(df.dtypes)

#print(df.columns)
    #for col in df.columns:
#print(df.isnull().sum())
#print(df.isna().sum())
# Out:
# Country     object
# AreaName    object
# Region      object
# DevName     object
# 1980         int64
# 1981         int64
# 1982         int64
# 1983         int64
# 1984         int64
# 1985         int64
# 1986         int64
# 1987         int64
# 1988         int64
# 1989         int64
# 1990         int64
# 1991         int64
# 1992         int64
# 1993         int64
# 1994         int64
# 1995         int64
# 1996         int64
# 1997         int64
# 1998         int64
# 1999         int64
# 2000         int64
# 2001         int64
# 2002         int64
# 2003         int64
# 2004         int64
# 2005         int64
# 2006         int64
# 2007         int64
# 2008         int64
# dtype: object

# %%
#Type, Coverage, Area, Reg, Dev
#df.drop(['Type'],axis=1)
#df.drop(['Type','Coverage','AREA','REG','DEV'],axis=1,inplace = True)
df.head()
# Out:
#             Country AreaName           Region             DevName  1980  1981  \
# 224     Afghanistan     Asia    Southern Asia  Developing regions    10    20
# 225         Albania   Europe  Southern Europe   Developed regions     0     0
# 226         Algeria   Africa  Northern Africa  Developing regions    10    50
# 227  American Samoa  Oceania        Polynesia  Developing regions     0     0
# 228         Andorra   Europe  Southern Europe   Developed regions     0     0
#
#      1982  1983  1984  1985  ...   1999  2000  2001  2002  2003  2004  2005  \
# 224    30    30    70   100  ...    270   100    20    40    70    80   110
# 225     0     0     0     0  ...     70   110   110   200   250   140   130
# 226    30    10    20    20  ...     30    20    30    60    20    20    50
# 227     0     0     0    20  ...      0     0     0     0     0     0     0
# 228    10     0     0     0  ...     10     0    10    10     0    10    10
#
#      2006  2007  2008
# ...

# %%
df.columns = [str(value) for value in df.columns]
#df['1980']

#df.rename(columns = {'OdName':'Country','RegName':'Region'},inplace = True)
#df.rename(columns={'pop':'population'}, inplace=True
#df.to_csv('Australia2.csv')
# Out:
# 224        10
# 225         0
# 226        10
# 227         0
# 228         0
# 229         0
# 230         0
# 231         0
# 232       570
# 233         0
# 234         0
# 235       280
# 236      4100
# 237         0
# 238        10
# 239        70
# 240       170
# 241         0
# 242         0
# 243       230
# 244         0
# 245         0
# 246        20
# 247         0
# 248        20
# 249         0
# 250        20
# 251       270
# 252         0
# 253        80
#         ...
# 418         0
# 419         0
# 420         0
# 421         0
# 422       130
# 423        20
# 424         0
# 425      1500
# 426         0
# 427         0
# 428        10
# 429        40
# 430         0
# 431        40
# 432     43540
# 433        70
# 434     10470
# 435         0
# 436       310
# 437         0
# 438       150
# 439        90
# 440       130
# 441         0
# 442         0
# 443        10
# 444       150
# 445       630
# 446      4060
# 447    184290
# ...

# %%
df['Total']=df.loc[:,'1980':'2008'].sum(axis=1)
#df.sort_values(by=['Total'],inplace = True, ascending=False)
df
# Out:
#                                                Country  \
# 224                                        Afghanistan
# 225                                            Albania
# 226                                            Algeria
# 227                                     American Samoa
# 228                                            Andorra
# 229                                             Angola
# 230                                           Anguilla
# 231                                Antigua and Barbuda
# 232                                          Argentina
# 233                                            Armenia
# 234                                              Aruba
# 235                                          Australia
# 236                                            Austria
# 237                                         Azerbaijan
# 238                                            Bahamas
# 239                                            Bahrain
# ...

# %%
print(df.columns)
# Out:
# Index(['Country', 'AreaName', 'Region', 'DevName', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        'Total'],
#       dtype='object')

# %%
#print(df.Country.value_counts())
print(df.Country.is_unique)
print(df.Region.is_unique)
print(df.set_index(['Country','Region']).index.is_unique) #very important
#print(df.set_index(['Country','Region']))


print(df[df['Total']== 0]['Country'].value_counts().sum())

# (or)

#df[df['Total']==0].index
#df.loc[230,'Country']
# Out:
# True
# False
# True
# 13

# %%
for col in df.columns:
    if not df[col].dtype == 'object':
        if df[col].isnull().all():
            print(col)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'/Users/khadarbashashaik/Desktop/Data Sciences/Notebook/titanic_dataset.csv')
print(df.describe())
#print(df.pclass.is_unique)
# Out:
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    654.000000     2.294882     0.381971    29.881135     0.498854
# std     378.020061     0.837836     0.486055    14.413500     1.041658
# min       0.000000     1.000000     0.000000     0.166700     0.000000
# 25%     327.000000     2.000000     0.000000    21.000000     0.000000
# 50%     654.000000     3.000000     0.000000    28.000000     0.000000
# 75%     981.000000     3.000000     1.000000    39.000000     1.000000
# max    1308.000000     3.000000     1.000000    80.000000     8.000000
#
#              parch        body
# count  1309.000000  121.000000
# mean      0.385027  160.809917
# std       0.865560   97.696922
# min       0.000000    1.000000
# 25%       0.000000   72.000000
# 50%       0.000000  155.000000
# 75%       0.000000  256.000000
# max       9.000000  328.000000

# %%
cols = df.columns
print(cols)

print(df.isnull().any().value_counts().sum())

for cols in df.columns:
    if (df[cols].isnull().any()):
        print(cols)
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'gender', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest'],
#       dtype='object')
# 15
# age
# fare
# cabin
# embarked
# boat
# body
# home.dest

# %%
for cols in df.columns:
    if df[cols].isnull().any() == True:
        #print(df[cols].isnull().any())
        print(df[cols].isnull().value_counts())
#df.drop(['home.dest','embarked'], axis = 1,inplace = True)
#print(df.dtypes)
k = []
#for value in df['fare']:
 #   k.append(str(value).replace('$',''))
    
df['fare'] = [str(value).strip().replace('$','') for value in df['fare']]
#value2.split() for value2 in df.fare
count = 1
for s in df.fare:
    count += 1
    if(len(s) == 3):
        print(count)
df.drop([1227],inplace = True)
print(df.describe())
# Out:
# False    1046
# True      263
# Name: age, dtype: int64
# False    1308
# True        1
# Name: fare, dtype: int64
# True     1014
# False     295
# Name: cabin, dtype: int64
# False    1307
# True        2
# Name: embarked, dtype: int64
# True     823
# False    486
# Name: boat, dtype: int64
# True     1188
# False     121
# Name: body, dtype: int64
# False    745
# True     564
# Name: home.dest, dtype: int64
# 1227
#         Unnamed: 0       pclass     survived          age        sibsp  \
# count  1308.000000  1308.000000  1308.000000  1045.000000  1308.000000
# mean    653.561927     2.294343     0.382263    29.888676     0.499235
# std     377.832106     0.837929     0.486126    14.418336     1.041965
# min       0.000000     1.000000     0.000000     0.166700     0.000000
# 25%     326.750000     2.000000     0.000000    21.000000     0.000000
# 50%     653.500000     3.000000     0.000000    28.000000     0.000000
# ...

# %%
df
# Out:
#       Unnamed: 0  pclass  survived  \
# 0              0       1         1
# 1              1       1         1
# 2              2       1         0
# 3              3       1         0
# 4              4       1         0
# 5              5       1         1
# 6              6       1         1
# 7              7       1         0
# 8              8       1         1
# 9              9       1         0
# 10            10       1         0
# 11            11       1         1
# 12            12       1         1
# 13            13       1         1
# 14            14       1         1
# 15            15       1         0
# 16            16       1         0
# 17            17       1         1
# 18            18       1         1
# 19            19       1         0
# 20            20       1         1
# 21            21       1         1
# 22            22       1         1
# 23            23       1         1
# 24            24       1         1
# ...

# %%
#survived = {0:'D',1:'A'}

#df.survived = [survived[col] for col in df.survived]
df.survived.value_counts()
df2 = df.groupby(['gender','survived'])
print(df2.groups)
# Out:
# ...
# {('female', 'A'): Int64Index([   0,    6,    8,   11,   12,   13,   17,   18,   21,   23,
#             ...
#             1223, 1244, 1247, 1257, 1258, 1260, 1261, 1286, 1290, 1300],
#            dtype='int64', length=339), ('female', 'D'): Int64Index([   2,    4,  105,  169,  286,  365,  369,  381,  382,  411,
#             ...
#             1211, 1230, 1231, 1265, 1267, 1273, 1276, 1279, 1304, 1305],
#            dtype='int64', length=126), ('male', 'A'): Int64Index([   1,    5,   14,   20,   22,   26,   29,   31,   37,   47,
#             ...
#             1196, 1228, 1232, 1233, 1236, 1238, 1240, 1254, 1256, 1277],
#            dtype='int64', length=161), ('male', 'D'): Int64Index([   3,    7,    9,   10,   15,   16,   19,   25,   30,   34,
#             ...
#             1296, 1297, 1298, 1299, 1301, 1302, 1303, 1306, 1307, 1308],
#            dtype='int64', length=682)}

# %%
print(df2.age.count())
# Out:
# gender  survived
# female  A           292
#         D            95
# male    A           135
#         D           523
# Name: age, dtype: int64

# %%
print(df.pclass.value_counts())
print(df.pclass.unique())
# Out:
# 3    708
# 1    323
# 2    277
# Name: pclass, dtype: int64
# [1 2 3]

# %%
dfgenderAge = df.sort_values(by=['age'], ascending = False)
dfgenderAge1 = dfgenderAge.head()

dfgenderAge1.gender.value_counts()
k = df.gender.value_counts()
dfGenderGroup = df.groupby(['gender'])
print(dfGenderGroup.age.mean())
dfAgeSurvivor = df.groupby(['survived'])
print(dfAgeSurvivor.age.mean())
dfGenderSurvivor = df.groupby(['survived','gender'])

print(dfGenderSurvivor.age.max())
# Out:
# gender
# female    28.704350
# male      30.585233
# Name: age, dtype: float64
# survived
# A    28.918228
# D    30.559196
# Name: age, dtype: float64
# survived  gender
# A         female    76.0
#           male      80.0
# D         female    63.0
#           male      74.0
# Name: age, dtype: float64

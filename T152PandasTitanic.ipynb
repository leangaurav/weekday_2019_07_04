# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic_dataset.csv')
print(df.head(4))
# Out:
#    Unnamed: 0  pclass  survived                                  name  gender  \
# 0           0       1         1         Allen, Miss. Elisabeth Walton  female
# 1           1       1         1        Allison, Master. Hudson Trevor    male
# 2           2       1         0          Allison, Miss. Helen Loraine  female
# 3           3       1         0  Allison, Mr. Hudson Joshua Creighton    male
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  $211.34        B5        S    2    NaN
# 1   0.9167      1      2  113781  $151.55   C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  $151.55   C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  $151.55   C22 C26        S  NaN  135.0
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
df.describe(include = 'all')
# Out:
#          Unnamed: 0       pclass     survived              name gender  \
# count   1309.000000  1309.000000  1309.000000              1309   1309
# unique          NaN          NaN          NaN              1307      2
# top             NaN          NaN          NaN  Kelly, Mr. James   male
# freq            NaN          NaN          NaN                 2    843
# mean     654.000000     2.294882     0.381971               NaN    NaN
# std      378.020061     0.837836     0.486055               NaN    NaN
# min        0.000000     1.000000     0.000000               NaN    NaN
# 25%      327.000000     2.000000     0.000000               NaN    NaN
# 50%      654.000000     3.000000     0.000000               NaN    NaN
# 75%      981.000000     3.000000     1.000000               NaN    NaN
# max     1308.000000     3.000000     1.000000               NaN    NaN
#
#                 age        sibsp        parch    ticket    fare        cabin  \
# ...

# %%
df.pclass.unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
print(df.columns)
print(df.dtypes)
# Out:
# Index(['Unnamed: 0', 'pclass', 'survived', 'name', 'gender', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body',
#        'home.dest'],
#       dtype='object')
# Unnamed: 0      int64
# pclass          int64
# survived        int64
# name           object
# gender         object
# age           float64
# sibsp           int64
# parch           int64
# ticket         object
# fare           object
# cabin          object
# embarked       object
# boat           object
# body          float64
# home.dest      object
# dtype: object

# %%
df2 = df.drop(['Unnamed: 0', 'ticket'], axis = 1)
df.drop(['Unnamed: 0', 'ticket'], axis = 1, inplace = True)
#df.drop(columns=['Unnamed: 0', 'ticket'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-eaf81df4eb0c> in <module>
# ----> 1 df2 = df.drop(['Unnamed: 0', 'ticket'], axis = 1)
#       2 df.drop(['Unnamed: 0', 'ticket'], axis = 1, inplace = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
# ...

# %%
print(df.age.count())
df.age.fillna(df.age.mean(), inplace = True)
print(df.age.count())
# Out:
# 1046
# 1309

# %%
df.isna().any()
# Out:
# pclass       False
# survived     False
# name         False
# gender       False
# age          False
# sibsp        False
# parch        False
# fare          True
# cabin         True
# embarked      True
# boat          True
# body          True
# home.dest     True
# dtype: bool

# %%
print(df.embarked.unique())
print()
print(df.embarked.value_counts())
# Out:
# ['S' 'C' nan 'Q']
#
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
d = df.fare.replace(r'\$' , '', regex = True)
print(d.head(2))
print(df.head(2))
print(dir(df.fare.str))
df.fare = df.fare.str.replace('$', '')
# Out:
# 0    211.34
# 1    151.55
# Name: fare, dtype: object
#    pclass  survived                            name  gender      age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0000      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9167      1
#
#    parch      fare    cabin embarked boat  body  \
# 0      0  $211.34        B5        S    2   NaN
# 1      2  $151.55   C22 C26        S   11   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# ...

# %%
print(df.fare.head())
print(df.fare.dtype)
df.fare = df.fare.astype(float)
print(df.fare.head())
print(df.fare.dtype)
# Out:
# 0    211.34
# 1    151.55
# 2    151.55
# 3    151.55
# 4    151.55
# Name: fare, dtype: object
# object
# 0    211.34
# 1    151.55
# 2    151.55
# 3    151.55
# 4    151.55
# Name: fare, dtype: float64
# float64

# %%
print(df.fare.count())
print(df.fare.isna().any())
df.fare[df.fare.isna()] # those rows where the data is NaN

print()
print(df.fare.isna().head())
print()
df.fare.fillna(df.fare.mean(), inplace = True)
print(df.fare.count())
# Out:
# 1309
# False
#
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: fare, dtype: bool
#
# 1309

# %%
print()
print(df.embarked.count())
# drop the row with missing data
r = np.where(df.embarked.isna())
print(r)
print(r[0])
df.drop(index = r[0], inplace = True)

print(df.count())
print(df.shape)
# Out:
# 1307
# (array([], dtype=int64),)
# []
# pclass       1307
# survived     1307
# name         1307
# gender       1307
# age          1307
# sibsp        1307
# parch        1307
# fare         1307
# cabin         293
# embarked     1307
# boat          484
# body          121
# home.dest     744
# dtype: int64
# (1307, 13)

# %%
g = df.groupby(['gender','survived'])
print(g.groups)
print(dir(g))
# Out:
# {('female', 0): Int64Index([   2,    4,  105,  169,  286,  365,  369,  381,  382,  411,
#             ...
#             1227, 1230, 1231, 1265, 1267, 1273, 1276, 1279, 1304, 1305],
#            dtype='int64', length=127), ('female', 1): Int64Index([   0,    6,    8,   11,   12,   13,   17,   18,   21,   23,
#             ...
#             1223, 1244, 1247, 1257, 1258, 1260, 1261, 1286, 1290, 1300],
#            dtype='int64', length=337), ('male', 0): Int64Index([   3,    7,    9,   10,   15,   16,   19,   25,   30,   34,
#             ...
#             1296, 1297, 1298, 1299, 1301, 1302, 1303, 1306, 1307, 1308],
#            dtype='int64', length=682), ('male', 1): Int64Index([   1,    5,   14,   20,   22,   26,   29,   31,   37,   47,
#             ...
#             1196, 1228, 1232, 1233, 1236, 1238, 1240, 1254, 1256, 1277],
#            dtype='int64', length=161)}
# ...

# %%
g.age.count()
# Out:
# gender  survived
# female  0           127
#         1           337
# male    0           682
#         1           161
# Name: age, dtype: int64

# %%
for idx in g:
    print(idx[0])
# Out:
# ('female', 0)
# ('female', 1)
# ('male', 0)
# ('male', 1)

# %%
for idx in g.groups: # like a dictionary
    print(idx)
    print(type(g.get_group(idx)))
# Out:
# ('female', 0)
# <class 'pandas.core.frame.DataFrame'>
# ('female', 1)
# <class 'pandas.core.frame.DataFrame'>
# ('male', 0)
# <class 'pandas.core.frame.DataFrame'>
# ('male', 1)
# <class 'pandas.core.frame.DataFrame'>

# %%
df.sort_values(by=['age', 'pclass'])
# Out:
#       pclass  survived                                               name  \
# 763        3         1            Dean, Miss. Elizabeth Gladys "Millvina"
# 747        3         0            Danbom, Master. Gilbert Sigvard Emanuel
# 1240       3         1                    Thomas, Master. Assad Alexander
# 427        2         1                          Hamalainen, Master. Viljo
# 657        3         1                             Baclini, Miss. Eugenie
# 658        3         1                      Baclini, Miss. Helene Barbara
# 1111       3         0                     Peacock, Master. Alfred Edward
# 359        2         1                      Caldwell, Master. Alden Gates
# 548        2         1                    Richards, Master. George Sibley
# 611        3         1                          Aks, Master. Philip Frank
# 1          1         1                     Allison, Master. Hudson Trevor
# 590        2         1                              West, Miss. Barbara J
# ...
